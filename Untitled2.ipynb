# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Load the dataset
data = pd.read_csv('/content/Telco-Customer-Churn.csv')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
data.drop(['customerID'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
categorical =list( data.dtypes[data.dtypes == object].index)

# %%
continious = data.dtypes[data.dtypes !=object].index

# %%
continious = list(continious)

# %%
continious.pop(0)
# Out:
# 'SeniorCitizen'

# %%
continious
# Out:
# ['tenure', 'MonthlyCharges']

# %%
categorical.append('SeniorCitizen')

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.shape
# Out:
# (7043, 20)

# %%
data['Churn'].value_counts()/data.shape[0]*100
# Out:
# Churn
# No     73.463013
# Yes    26.536987
# Name: count, dtype: float64

# %%
data.duplicated().sum()
# Out:
# 22

# %%
data.shape
# Out:
# (7043, 20)

# %%
data.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
sns.set_theme(style="darkgrid", palette="Set2") # Change palette name to "Set2"
sns.countplot(data=data, y="Churn",orient='h')
# Out:
# <Axes: xlabel='count', ylabel='Churn'>

# %%
data.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
categorical.remove('TotalCharges')

# %%
categorical
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'Churn',
#  'SeniorCitizen']

# %%
for c in categorical:
  plt.figure(figsize=(12,6))
  sns.countplot(data=data, x=c,hue='Churn')
  plt.title(f"count of {c}")
  plt.show()
  print("  ")
  print("-----------")
# Out:
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------
#
# -----------

# %%
continious
# Out:
# ['tenure', 'MonthlyCharges']

# %%
data.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
data['TotalCharges']= data['TotalCharges'].replace(' ',0).astype('float32')

# %%
data.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float32
# Churn                object
# dtype: object

# %%
continious.append('TotalCharges')

# %%
def kdeplot(feature):
  plt.figure(figsize=(9,4))
  plt.title(f"KDE plot {feature}")
  ax0 = sns.kdeplot(data[data.Churn=="No"][feature], label="Churn: No")
  ax1 = sns.kdeplot(data[data.Churn=="Yes"][feature], label="Churn:Yes")
  plt.legend()
  plt.show()

# %%
for co in continious:
  kdeplot(co)

# %%
sns.scatterplot(data = data,x="MonthlyCharges",y="tenure",hue="Churn")
# Out:
# <Axes: xlabel='MonthlyCharges', ylabel='tenure'>

# %%
sns.scatterplot(data = data,x="TotalCharges",y="tenure",hue="Churn")
# Out:
# <Axes: xlabel='TotalCharges', ylabel='tenure'>

# %%
# Convert relevant columns to numerical data types if necessary.
# For example, if 'gender' should be treated as categorical:
data['gender'] = data['gender'].astype('category').cat.codes

# Calculate the correlation matrix only for numerical features.
numerical_features = data.select_dtypes(include=['number']).columns
correlation_matrix = data[numerical_features].corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                   gender  SeniorCitizen    tenure  MonthlyCharges  \
# gender          1.000000      -0.001874  0.005106       -0.014569
# SeniorCitizen  -0.001874       1.000000  0.016567        0.220173
# tenure          0.005106       0.016567  1.000000        0.247900
# MonthlyCharges -0.014569       0.220173  0.247900        1.000000
# TotalCharges   -0.000080       0.103006  0.826178        0.651174
#
#                 TotalCharges
# gender             -0.000080
# SeniorCitizen       0.103006
# tenure              0.826178
# MonthlyCharges      0.651174
# TotalCharges        1.000000

# %% [markdown]
# Dta preprocessing

# %%
x = data.drop(["Churn"],axis=1)
y = data["Churn"]

# %%
# !pip install scikit-learn --upgrade # Ensure scikit-learn is installed and updated.

from sklearn.preprocessing import MinMaxScaler # Import with the correct class name.

mmscaler = MinMaxScaler()
x['tenure'] = mmscaler.fit_transform(x[['tenure']]) # Correct the fit_transform call.
x['TotalCharges']= mmscaler.fit_transform(x[['TotalCharges']]) # Correct the fit_transform call.
x['MonthlyCharges']= mmscaler.fit_transform(x[['MonthlyCharges']]) # Correct the fit_transform call.

# %%
x.head()
# Out:
#    gender  SeniorCitizen Partner Dependents    tenure PhoneService  \
# 0       0              0     Yes         No  0.013889           No
# 1       1              0      No         No  0.472222          Yes
# 2       1              0      No         No  0.027778          Yes
# 3       1              0      No         No  0.625000           No
# 4       0              0      No         No  0.027778          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
categorical.remove('Churn')

# %%
x[categorical].head()
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0       0     Yes         No           No  No phone service             DSL
# 1       1      No         No          Yes                No             DSL
# 2       1      No         No          Yes                No             DSL
# 3       1      No         No           No  No phone service             DSL
# 4       0      No         No          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
for c in categorical:
  encoder.fit(x[c])
  x[c] = encoder.transform(x[c])
  mapping = dict(zip(encoder.classes_, encoder.transform(encoder.classes_)))
  print(c, ":",mapping)
# Out:
# gender : {0: 0, 1: 1}
# Partner : {'No': 0, 'Yes': 1}
# Dependents : {'No': 0, 'Yes': 1}
# PhoneService : {'No': 0, 'Yes': 1}
# MultipleLines : {'No': 0, 'No phone service': 1, 'Yes': 2}
# InternetService : {'DSL': 0, 'Fiber optic': 1, 'No': 2}
# OnlineSecurity : {'No': 0, 'No internet service': 1, 'Yes': 2}
# OnlineBackup : {'No': 0, 'No internet service': 1, 'Yes': 2}
# DeviceProtection : {'No': 0, 'No internet service': 1, 'Yes': 2}
# TechSupport : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingTV : {'No': 0, 'No internet service': 1, 'Yes': 2}
# StreamingMovies : {'No': 0, 'No internet service': 1, 'Yes': 2}
# Contract : {'Month-to-month': 0, 'One year': 1, 'Two year': 2}
# PaperlessBilling : {'No': 0, 'Yes': 1}
# PaymentMethod : {'Bank transfer (automatic)': 0, 'Credit card (automatic)': 1, 'Electronic check': 2, 'Mailed check': 3}
# SeniorCitizen : {0: 0, 1: 1}

# %%
x
# Out:
#       gender  SeniorCitizen  Partner  Dependents    tenure  PhoneService  \
# 0          0              0        1           0  0.013889             0
# 1          1              0        0           0  0.472222             1
# 2          1              0        0           0  0.027778             1
# 3          1              0        0           0  0.625000             0
# 4          0              0        0           0  0.027778             1
# ...      ...            ...      ...         ...       ...           ...
# 7038       1              0        1           1  0.333333             1
# 7039       0              0        1           1  1.000000             1
# 7040       0              0        1           1  0.152778             0
# 7041       1              1        1           0  0.055556             1
# 7042       1              0        0           0  0.916667             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
x.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
y = encoder.fit_transform(y) # Corrected method name from fit_transfrom to fit_transform

# %%
len(y)
# Out:
# 7043

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) # Changed x1, y1 to x, y=42)

# %%
from sklearn.feature_selection import SelectKBest, f_classif
kbest = SelectKBest(f_classif, k=5)
x_train_selected = kbest.fit_transform(x_train, y_train)
x_test_selected = kbest.transform(x_test)

# %%
x_train_selected = x_train.iloc[:, kbest.get_support()]

# %%
x_test_selected = x_test.iloc[:, kbest.get_support()]

# %%
x_train.shape
# Out:
# (5634, 19)

# %%
y_train.shape
# Out:
# (5634,)

# %%
# In ipython-input-120-9833b832fd03, change:
x_train_Selected = x_test[x_train.columns[kbest.get_support()]]
# To:
x_train_Selected = x_train[x_train.columns[kbest.get_support()]]

# Then, create x_test_selected using the same selected columns:
x_test_selected = x_test[x_train.columns[kbest.get_support()]]

# Now, your model fitting should work correctly:
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

model1 = DecisionTreeClassifier()
model1.fit(x_train_Selected, y_train)
ans1 = model1.predict(x_test_selected)

# %%
score1 = accuracy_score(y_test,ans1)
score1*100
# Out:
# 73.24343506032646

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Correct the syntax to pass ans1 as a separate argument
cm = confusion_matrix(y_test, ans1)
sns.heatmap(cm, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,ans1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82      1036
#            1       0.49      0.49      0.49       373
#
#     accuracy                           0.73      1409
#    macro avg       0.66      0.66      0.66      1409
# weighted avg       0.73      0.73      0.73      1409

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier()
# Fixed the typo in variable name from x_train_selectedlected to x_train_Selected
model2.fit(x_train_Selected,y_train)
ans2 = model2.predict(x_test_selected)

# %%
score2= accuracy_score(y_test,ans1)
score2*100
# Out:
# 73.24343506032646

# %%
cm = confusion_matrix(y_test, ans2)
sns.heatmap(cm, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,ans2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      1036
#            1       0.55      0.47      0.51       373
#
#     accuracy                           0.76      1409
#    macro avg       0.69      0.67      0.68      1409
# weighted avg       0.75      0.76      0.75      1409

# %%
sns.countplot(data=data, x="Churn")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
from imblearn.over_sampling import RandomOverSampler

# %%
ros = RandomOverSampler(random_state=42)
x1, y1 = ros.fit_resample(x, y)

# %%
x1.shape
# Out:
# (10348, 19)

# %%
y1 = pd.Series(y1)
y1.value_counts() # Changed 'value_count' to 'value_counts'
# Out:
# 0    5174
# 1    5174
# Name: count, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size=0.2,random_state=42)

# %%
from sklearn.feature_selection import SelectKBest, f_classif
kbest = SelectKBest(f_classif, k=5)
x_train_selected = kbest.fit_transform(x_train, y_train)
x_test_selected = kbest.transform(x_test)

# %%
x_train_selected = x_train.iloc[:, kbest.get_support()]

# %%
x_test_selected = x_test.iloc[:, kbest.get_support()]

# %%
x_train.shape
# Out:
# (8278, 19)

# %%
y_train.shape
# Out:
# (8278,)

# %%
# In ipython-input-120-9833b832fd03, change:
x_train_Selected = x_test[x_train.columns[kbest.get_support()]]
# To:
x_train_Selected = x_train[x_train.columns[kbest.get_support()]]

# Then, create x_test_selected using the same selected columns:
x_test_selected = x_test[x_train.columns[kbest.get_support()]]

# Now, your model fitting should work correctly:
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

model1 = DecisionTreeClassifier()
model1.fit(x_train_Selected, y_train)
ans1 = model1.predict(x_test_selected)

# %%
score1 = accuracy_score(y_test,ans1)
score1*100
# Out:
# 87.48792270531402

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Correct the syntax to pass ans1 as a separate argument
cm = confusion_matrix(y_test, ans1)
sns.heatmap(cm, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,ans1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.81      0.86      1021
#            1       0.84      0.94      0.88      1049
#
#     accuracy                           0.87      2070
#    macro avg       0.88      0.87      0.87      2070
# weighted avg       0.88      0.87      0.87      2070

# %%
from sklearn.ensemble import RandomForestClassifier
model2 = RandomForestClassifier()
# Fixed the typo in variable name from x_train_selectedlected to x_train_Selected
model2.fit(x_train_Selected,y_train)
ans2 = model2.predict(x_test_selected)

# %%
score2= accuracy_score(y_test,ans1)
score2*100
# Out:
# 87.48792270531402

# %%
cm = confusion_matrix(y_test, ans2)
sns.heatmap(cm, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,ans2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.82      0.87      1021
#            1       0.84      0.94      0.89      1049
#
#     accuracy                           0.88      2070
#    macro avg       0.89      0.88      0.88      2070
# weighted avg       0.89      0.88      0.88      2070

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
param_grid = {
    'n_estimators':[None,100,200,300,400,400],
    'max_depth':[None, 10,20,30,40],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4],
    'bootstrap':[True,False]
}
#Ensure rf is not indented and aligned with param_grid definition
rf = RandomForestClassifier()
rf_random = RandomizedSearchCV(estimator=rf,param_distributions=param_grid,n_iter=10,cv=3,verbose=2,random_state=42,n_jobs=-1) # Fixed typo: verboss -> verbose , and n_jobs=-1 is usually the best for single machine
rf_random.fit(x_train_selected,y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 3 fits failed out of a total of 30.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 666, in _validate_params
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_depth': 20,
#  'bootstrap': False}

# %%
ans2 = rf_random.best_estimator_.predict(x_test_selected) # Call predict on the best_estimator_ attribute

# %%
ans3 = rf_random.best_estimator_.predict(x_test_selected)

# %%
score3= accuracy_score(y_test,ans3)
score3*100
# Out:
# 87.72946859903382

# %%
cm = confusion_matrix(y_test, ans3)
sns.heatmap(cm, annot=True, fmt='g')
# Out:
# <Axes: >

# %%
print(classification_report(y_test,ans3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87      1021
#            1       0.84      0.94      0.89      1049
#
#     accuracy                           0.88      2070
#    macro avg       0.88      0.88      0.88      2070
# weighted avg       0.88      0.88      0.88      2070

# %%
"""gender : {0: 0, 1: 1}
Partner : {'No': 0, 'Yes': 1}
Dependents : {'No': 0, 'Yes': 1}
PhoneService : {'No': 0, 'Yes': 1}
MultipleLines : {'No': 0, 'No phone service': 1, 'Yes': 2}
InternetService : {'DSL': 0, 'Fiber optic': 1, 'No': 2}
OnlineSecurity : {'No': 0, 'No internet service': 1, 'Yes': 2}
OnlineBackup : {'No': 0, 'No internet service': 1, 'Yes': 2}
DeviceProtection : {'No': 0, 'No internet service': 1, 'Yes': 2}
TechSupport : {'No': 0, 'No internet service': 1, 'Yes': 2}
StreamingTV : {'No': 0, 'No internet service': 1, 'Yes': 2}
StreamingMovies : {'No': 0, 'No internet service': 1, 'Yes': 2}
Contract : {'Month-to-month': 0, 'One year': 1, 'Two year': 2}
PaperlessBilling : {'No': 0, 'Yes': 1}
PaymentMethod : {'Bank transfer (automatic)': 0, 'Credit card (automatic)': 1, 'Electronic check': 2, 'Mailed check': 3}
SeniorCitizen : {0: 0, 1: 1}"""
# Out:
# "gender : {0: 0, 1: 1}\nPartner : {'No': 0, 'Yes': 1}\nDependents : {'No': 0, 'Yes': 1}\nPhoneService : {'No': 0, 'Yes': 1}\nMultipleLines : {'No': 0, 'No phone service': 1, 'Yes': 2}\nInternetService : {'DSL': 0, 'Fiber optic': 1, 'No': 2}\nOnlineSecurity : {'No': 0, 'No internet service': 1, 'Yes': 2}\nOnlineBackup : {'No': 0, 'No internet service': 1, 'Yes': 2}\nDeviceProtection : {'No': 0, 'No internet service': 1, 'Yes': 2}\nTechSupport : {'No': 0, 'No internet service': 1, 'Yes': 2}\nStreamingTV : {'No': 0, 'No internet service': 1, 'Yes': 2}\nStreamingMovies : {'No': 0, 'No internet service': 1, 'Yes': 2}\nContract : {'Month-to-month': 0, 'One year': 1, 'Two year': 2}\nPaperlessBilling : {'No': 0, 'Yes': 1}\nPaymentMethod : {'Bank transfer (automatic)': 0, 'Credit card (automatic)': 1, 'Electronic check': 2, 'Mailed check': 3}\nSeniorCitizen : {0: 0, 1: 1}"

# %% [markdown]
# Predicative system

# %%
inp = []
for a in x_train_selected.columns:
  f = int(input(f"enter {a} : "))
  inp.append(f)
# Out:
# enter tenure : 1
# enter OnlineSecurity : 2
# enter TechSupport : 0
# enter Contract : 3
# enter TotalCharges : 4

# %%
inp
# Out:
# [1, 2, 0, 3, 4]

# %%
import numpy as np
i_array = np.array(inp)
i_array = i_array.reshape(1,-1)
result = rf_random.best_estimator_.predict(i_array)
print(f"Result from model:{result}")
if result[0] ==9:
  print("Customer will churn")
else:
  print("Customer will not churn")
# Out:
# Result from model:[0]
# Customer will not churn
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
